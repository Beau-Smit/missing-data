# %%
import remove_data
import simulate_data
import seaborn as sns
# %load_ext autoreload
# %autoreload 2
sns.set(rc={"figure.figsize":(6, 6)}) #width=3, #height=4

sim_df = simulate_data.sim_data(**simulate_data.sim_params)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sim_df.head()
# Out:
#   Group  Age        Income  NChild  InCensus  Discrete_LowLikelihood_0  \
# 0     B   94  37241.535598       0         1                         0
# 1     A  100  41741.577601       0         1                         0
# 2     B   31  31844.663771       1         1                         0
# 3     B   70  16200.489601       1         0                         1
# 4     B   32  57719.758166       2         1                         0
#
#    Discrete_LowLikelihood_1  Discrete_LowLikelihood_2  \
# 0                         0                         0
# 1                         0                         0
# 2                         0                         0
# 3                         1                         0
# 4                         0                         0
#
#    Discrete_LowLikelihood_3  Discrete_LowLikelihood_4  ...  \
# 0                         0                         0  ...
# 1                         0                         0  ...
# ...

# %%
sns.heatmap((sim_df.iloc[:65,1:].applymap(lambda x: x!=0)).T)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data = sim_df, x = 'Age', y = 'NChild')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='NChild'>

# %%
sns.barplot(data = sim_df, x = 'Group', y = 'InCensus')
# Out:
# <AxesSubplot:xlabel='Group', ylabel='InCensus'>

# %%
import seaborn as sns
sns.pairplot(sim_df.loc[:,['Age','Income', 'NChild', 'InCensus']])

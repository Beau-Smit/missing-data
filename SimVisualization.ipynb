# %%
import remove_data
import simulate_data
import seaborn as sns

sim_df = simulate_data.sim_data(**simulate_data.sim_params)

# %%
sim_df.head()
# Out:
#   Group  Age        Income  NChild  InCensus  Occupants.ChildrenGrandchildren  \
# 0     A   58  42284.256218       1         1                                0
# 1     A   25  62331.447250       0         0                                0
# 2     A   58  53114.524634       0         1                                0
# 3     A   53  56342.739540       1         1                                0
# 4     A   47  59315.462211       0         0                                0
#
#    Occupants.Relatives  Occupants.Nonrelatives  Occupants.Temporary  \
# 0                    0                       0                    0
# 1                    0                       0                    0
# 2                    0                       1                    0
# 3                    0                       0                    0
# 4                    0                       0                    0
#
#    Occupants.NoAdditional  Housing.Owned_PaidOff  Housing.Owned_Mortgage  \
# ...

# %%
sns.lineplot(data = sim_df, x = 'Age', y = 'NChild')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='NChild'>

# %%
sns.barplot(data = sim_df, x = 'Group', y = 'InCensus')
# Out:
# <AxesSubplot:xlabel='Group', ylabel='InCensus'>

# %%
import seaborn as sns
sns.pairplot(sim_df.loc[:,['Age','Income', 'NChild', 'InCensus']])

# %% [markdown]
# Example uses of the missingess functions:

# %%
mcar = remove_data.missing_at_random(sim_df, perc_remove = .1, rand_seed=43254)
sns.heatmap(mcar)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-cc630fd5cecc> in <module>
#       1 mcar = remove_data.missing_at_random(sim_df, perc_remove = .1, rand_seed=43254)
# ----> 2 sns.heatmap(mcar)
#
# ~/miniconda3/envs/CAPP/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/miniconda3/envs/CAPP/lib/python3.9/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     533     """
#     534     # Initialize the plotter object
# ...

# %%
# 
truncated = remove_data.missing_conditional_continuous(sim_df, target_col='Income', reference_col='Income', threshold= 80000)
